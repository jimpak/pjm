# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import json
import urllib.request # requests를 사용해도 됨.

client_id = "ijm7fpfcH9iWm5LBifhk"
client_secret = "LUilHrShRi"
encText = urllib.parse.quote("취업")

for i in range(1, 11):
    str1 = ""
    
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&start=" + str(i) + "&display=100" # JSON 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

    # urllib.request.urlopen(url)
    request = urllib.request.Request(url) # request 객체 생성
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # response로 가져온 객체가 존재한다면
        response_body = response.read()
        # print(response_body)

        # print(response_body.decode('utf-8'))
        # items=response_body.decode('utf-8')['items'] # items를 읽어오지 못함.

        res_body = json.loads(response_body.decode('utf-8'))
        items = res_body['items'] # json으로 객체를 저장하면 items를 읽어올수 있음.
        for item in items:
            str1 += item['title']
            str1 += item['description']
            # print(item['title'])
            # print(item['description'])
            # print()
        print(str1)
    else:
        print("Error Code:" + rescode)
# Out:
# 제과제빵전문학교 안전하게 <b>취업</b>까지하지만, 제가 좋아하는 것을 포기하고 싶지 않았고 다른 곳 보다 <b>취업</b>률이 높았기에 큰 고민을 하지... <b>취업</b>을 하게 된다고 하더라도 이론적으로 많이 알고 있는 사람보다는 실무경험이 있는 사람들을 더... 유아주산 온라인 강의로 교육과 <b>취업</b>을 같이!기관에서 <b>취업</b>준비도 해줬기 때문에 욕심이 생겨서 도전해보고 싶었죠 아이가 어느정도 클 떼 다시 경제활동을 하고 싶었는데 타이밍이 딱 좋은 시기었죠 엄마표로 자녀도 주산 교육을 해주고 <b>취업</b>까지 다... 부산컴퓨터학원 <b>취업</b> 대비 포토샵 수업과정저는 실제로 부산컴퓨터학원에서 포토샵 수업을 들은 후 현재 <b>취업</b>했습니다! 그래서 오늘은 입문자인 제가 어떻게 학원 수업을 통해 <b>취업</b> 대비할 수 있었는지 이야기해드릴게요+_+ 준비 초반, 배워보고 싶었던... 부천 사회복지사2급 <b>취업</b> 잘하는 방법당장이라도 <b>취업</b>을 해야했던 저에게는 꽤 긴 시간이었거든요 부천 사회복지사2급을 취득하기 위해서... 아무튼 제가 어떻게 땄는지 한 번 적어봤는데 <b>취업</b>에 도움이 되는 것들을 공유를 해보자면 컴퓨터... 사회복지사2급 <b>취업</b>분야 자격증 따는 방법사회복지사2급자격증취득방법에 대하여 알아보고 <b>취업</b>까지 성공한 42세 박O지라고 합니다. 여느때와 다른것 없이 작은 회사 에 <b>취업</b>하여 직장을 다니고 있던 평범한 주부였는데요. 컴퓨터를 잘 다루지 못했을... 필라테스 강사 자격증 <b>취업</b>과 면접, 이력서지금까지의 레슨 경력과 필라테스 강사들을 교육해온 경험들을 토대로 <b>취업</b>과 면접에 대한 노하우와 사실을 공유해 볼게요! https://blog.naver.com/guswls7453/223329556533 필라테스 강사 <b>취업</b> 과연 어려울까? -인터넷에... 승무원학원, 입시부터 <b>취업</b>까지 솔직후기대학입시
# ...

# %%
from konlpy.tag import *
okt = Okt()
nouns = okt.nouns(str1)
nouns
# Out:
# ['아동',
#  '요리',
#  '지도사',
#  '급',
#  '두',
#  '번',
#  '취업',
#  '성공',
#  '자격증',
#  '취업',
#  '교육과정',
#  '지금',
#  '생각',
#  '편이',
#  '교육과정',
#  '실무',
#  '위주',
#  '자격증',
#  '후',
#  '취업',
#  '위',
#  '서비스',
#  '다른',
#  '곳',
#  '초등',
#  '댄스',
#  '학원',
#  '인강',
#  '취업',
#  '취득',
#  '취업',
#  '이',
#  '방송',
#  '댄스',
#  '지도사',
#  '나이',
#  '전공',
#  '학력',
#  '초보',
#  '강사',
#  '제',
#  '경력',
#  '전문',
#  '커리큘럼',
#  '취업',
#  '이',
#  '구로',
#  '컴퓨터',
#  '학원',
#  '국비',
#  '지원',
#  '취업',
#  '준비',
#  '대학교',
#  '졸업',
#  '취업',
#  '준비',
#  '해',
#  '전공',
#  '도전',
#  '기존',
#  '강',
#  '사진',
#  '취업',
#  '지원',
#  '확인',
#  '가지',
#  '조건',
#  '정',
#  '이',
#  '조건',
#  '정',
#  '생각',
#  '곳',
#  '기능사',
#  '일',
#  '취업',
#  '연봉',
#  '시험',
#  '정보',
#  '취업',
#  '도',
#  '준비',
#  '자만',
#  '수',
#  '분야',
#  '가기',
#  '위',
#  '자세',
#  '사람',
#  '뽑기',
#  '때문',
#  '요',
#  '준비',
#  '오늘',
#  '포스팅',
#  '기능사',
#  '일',
#  '취업',
#  '연봉',
#  '분당',
#  '미용',
#  '학원',
#  '취업',
#  '준비',
#  '생각',
#  '합격',
#  '률',
#  '그',
#  '후',
#  '취업',
#  '위',
# ...

# %%
from collections import Counter
c1 = Counter(nouns)
cd = dict()
for key, value in c1.items():
    if(len(key) > 1 and value > 1):
        cd[key] = value
cd
# Out:
# {'아동': 4,
#  '요리': 5,
#  '지도사': 22,
#  '취업': 330,
#  '성공': 4,
#  '자격증': 15,
#  '교육과정': 8,
#  '지금': 3,
#  '생각': 13,
#  '실무': 11,
#  '서비스': 5,
#  '초등': 4,
#  '댄스': 4,
#  '학원': 13,
#  '취득': 12,
#  '방송': 3,
#  '나이': 2,
#  '전공': 5,
#  '강사': 17,
#  '경력': 10,
#  '전문': 11,
#  '커리큘럼': 2,
#  '컴퓨터': 5,
#  '국비': 4,
#  '지원': 32,
#  '준비': 49,
#  '졸업': 6,
#  '도전': 7,
#  '기존': 2,
#  '사진': 7,
#  '가지': 6,
#  '조건': 10,
#  '기능사': 2,
#  '연봉': 9,
#  '시험': 9,
#  '정보': 9,
#  '분야': 13,
#  '사람': 4,
#  '때문': 6,
#  '오늘': 15,
#  '포스팅': 4,
#  '분당': 2,
#  '미용': 2,
#  '합격': 4,
#  '진행': 5,
#  '유화': 2,
#  '제공': 9,
#  '후기': 29,
#  '미술': 6,
#  '수업': 8,
#  '기관': 6,
#  '방과후': 11,
#  '교실': 2,
#  '교육': 22,
#  '자격': 10,
#  '게임': 3,
#  '기획': 2,
#  '프로젝트': 6,
#  '시스템': 2,
#  '자신': 2,
#  '결정': 2,
#  '이유': 5,
#  '무엇': 3,
#  '하나요': 3,
#  '국내': 3,
#  '외국인': 8,
#  '비자': 20,
#  '종류': 4,
#  '기업': 7,
#  '외국': 4,
#  '인력': 5,
#  '지정': 2,
#  '직종': 11,
#  '해외': 3,
#  '고용': 5,
#  '유학': 6,
#  '통해': 6,
#  '학생': 3,
#  '집중': 3,
#  '상황': 2,
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

font_path = 'data/fonts/MALGUNBD.TTF'
wc = WordCloud(width=1000, height=1000, background_color='white', font_path=font_path, colormap='Wistia')

plt.imshow(wc.generate_from_frequencies(cd))
plt.axis('off')
plt.show()
