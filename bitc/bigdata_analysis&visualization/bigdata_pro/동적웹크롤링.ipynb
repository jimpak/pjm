# %%
# ! pip install selenium
# ! pip install webdriver_manager

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('http://www.google.com/ncr')

target = driver.find_element(By.CSS_SELECTOR, "[name='q']")
target.send_keys("파이썬")
target.send_keys(Keys.ENTER)

# %%
driver.quit()

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.get('http://www.naver.com')
target = driver.find_element(By.ID, 'query')
target.send_keys("파이썬")
target.send_keys(Keys.ENTER)

# %%
driver.quit()

# %%
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.implicitly_wait(3)
driver.get('https://www.starbucks.co.kr/store/store_map.do')

# target = driver.find_elements(By.CLASS_NAME, "quickResultLstCon")
target = driver.find_elements(By.CSS_SELECTOR, '#mCSB_1_container > ul > li')
print(type(target))
for i in target:
    print(i.text)

# %%
driver.quit()

# %%
import urllib.request as req
from bs4 import BeautifulSoup as bs
res = req.urlopen('https://www.starbucks.co.kr/store/store_map.do')
res=res.read().decode('utf-8')
soup=bs(res, 'html.parser')
# li=soup.select_one("#mCSB_1_container > ul > li")
li_list=soup.find_all("li", class_="quickResultLstCon")
print(li_list)
# Out:
# []

# %%
import time
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.implicitly_wait(1)
driver.get('https://www.starbucks.co.kr/store/store_map.do')
time.sleep(1)
local = driver.find_element(By.CLASS_NAME, "loca_search")
local.click()
time.sleep(1)
f_link = driver.find_element(By.CSS_SELECTOR, 'div.loca_step1_cont > ul > li:nth-child(6) > a')
f_link.click()
time.sleep(1)
s_link = driver.find_element(By.CSS_SELECTOR, '#mCSB_2_container > ul > li:nth-child(8) > a')
s_link.click()
time.sleep(1)
shop_list = driver.find_elements(By.CSS_SELECTOR, '#mCSB_3_container > ul > li')
for shop in shop_list:
    print(shop.text)
# Out:
# 서면문화로
# 부산광역시 부산진구 서면문화로 10 (부전동)
# 1522-3232
# 리저브 매장 2번
# 서면엠디엠타워
# 부산광역시 부산진구 중앙대로 639 (범천동)
# 1522-3232
# 리저브 매장 2번
# 초읍대공원
# 부산광역시 부산진구 성지곡로 6 (초읍동)
# 1522-3232
# 리저브 매장 2번

# %%
count = 0
temp_list = []
total = len(shop_list)

for shop in shop_list:
    count += 1
    shop_lat = shop.get_attribute('data-lat')
    shop_long = shop.get_attribute('data-long')
    shop_name = shop.get_attribute('data-name')
    shopinfo = shop.find_element(By.TAG_NAME, 'p')
    # print(shopinfo.text)
    arr_shopinfo = shopinfo.text.split("\n")
    # print(arr_shopinfo[0], arr_shopinfo[1])
    if(len(arr_shopinfo) == 2):
        addr = arr_shopinfo[0]
        phone = arr_shopinfo[1]
    else:
        addr = "-"
        phone = "-"
    # print(shop_name, shop_lat, shop_long, addr, phone)

    temp_list.append((shop_name, shop_lat, shop_long, addr, phone))

    if(count != total and count % 3 == 0):
        driver.execute_script("var su=arguments[0]; \
                              var dom=document.querySelectorAll('#mCSB_3_container > ul > li')[su]; \
                              dom.scrollIntoView();", count)
temp_list
# Out:
# [('서면문화로',
#   '35.159056',
#   '129.057527',
#   '부산광역시 부산진구 서면문화로 10 (부전동)',
#   '1522-3232'),
#  ('서면엠디엠타워',
#   '35.150017',
#   '129.058489',
#   '부산광역시 부산진구 중앙대로 639 (범천동)',
#   '1522-3232'),
#  ('초읍대공원',
#   '35.1828193069829',
#   '129.04748360769',
#   '부산광역시 부산진구 성지곡로 6 (초읍동)',
#   '1522-3232'),
#  ('서면트레이더스',
#   '35.163918',
#   '129.052684',
#   '부산광역시 부산진구 시민공원로 31 (부암동)',
#   '1522-3232'),
#  ('서면중앙',
#   '35.156863',
#   '129.058076',
#   '부산광역시 부산진구 서면로68번길 1 (부전동)',
#   '1522-3232'),
#  ('서면메디컬거리',
#   '35.157961',
#   '129.05740949999995',
#   '부산광역시 부산진구 가야대로 783-1, 1층 (부전동)',
#   '1522-3232'),
#  ('서면센트럴스퀘어',
#   '35.15151',
#   '129.061139',
#   '부산광역시 부산진구 중앙대로666번길 50 (부전동)',
#   '1522-3232'),
#  ('부전역',
#   '35.16183',
#   '129.061933',
#   '부산광역시 부산진구 중앙대로 777, 서면호텔 복합시설1,2층 (부전동)',
#   '1522-3232'),
#  ('서면역',
#   '35.1579735',
#   '129.05999229999998',
#   '부산광역시 부산진구 서전로 1 (부전동)',
#   '1522-3232'),
#  ('부산서면',
#   '35.154098',
#   '129.061562',
# ...

# %%
driver.quit()

# %%
import time
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
driver.implicitly_wait(1)
driver.get('https://www.starbucks.co.kr/store/store_map.do')
time.sleep(1)
local = driver.find_element(By.CLASS_NAME, "loca_search")
local.click()
time.sleep(1)
f_link = driver.find_element(By.CSS_SELECTOR, 'div.loca_step1_cont > ul > li:nth-child(1) > a')
f_link.click()
time.sleep(1)
s_link = driver.find_element(By.CSS_SELECTOR, '#mCSB_2_container > ul > li:nth-child(2) > a')
s_link.click()
time.sleep(1)
shop_list = driver.find_elements(By.CSS_SELECTOR, '#mCSB_3_container > ul > li')
for shop in shop_list:
    print(shop.text)
# Out:
# 강남세곡DT
# 서울특별시 강남구 헌릉로 727 (세곡동)
# 1522-3232
# 리저브 매장 2번
# 역삼이마트
# 서울특별시 강남구 역삼로 310 (역삼동)
# 1522-3232
# 리저브 매장 2번
# 청담역
# 서울특별시 강남구 삼성로 709 (청담동)
# 1522-3232
# 리저브 매장 2번

# %%
count = 0
temp_list = []
total = len(shop_list)

for shop in shop_list:
    count += 1
    shop_lat = shop.get_attribute('data-lat')
    shop_long = shop.get_attribute('data-long')
    shop_name = shop.get_attribute('data-name')
    shopinfo = shop.find_element(By.TAG_NAME, 'p')
    # print(shopinfo.text)
    arr_shopinfo = shopinfo.text.split("\n")
    # print(arr_shopinfo[0], arr_shopinfo[1])
    if(len(arr_shopinfo) == 2):
        addr = arr_shopinfo[0]
        phone = arr_shopinfo[1]
    else:
        addr = "-"
        phone = "-"
    # print(shop_name, shop_lat, shop_long, addr, phone)

    temp_list.append((shop_name, shop_lat, shop_long, addr, phone))

    if(count != total and count % 3 == 0):
        driver.execute_script("var su=arguments[0]; \
                              var dom=document.querySelectorAll('#mCSB_3_container > ul > li')[su]; \
                              dom.scrollIntoView();", count)
temp_list
# Out:
# [('강남세곡DT',
#   '37.466993809277',
#   '127.118330806807',
#   '서울특별시 강남구 헌릉로 727 (세곡동)',
#   '1522-3232'),
#  ('역삼이마트', '37.499367', '127.048425', '서울특별시 강남구 역삼로 310 (역삼동)', '1522-3232'),
#  ('청담역',
#   '37.5194407323478',
#   '127.049552661542',
#   '서울특별시 강남구 삼성로 709 (청담동)',
#   '1522-3232'),
#  ('삼성동',
#   '37.510843366121534',
#   '127.06363342044263',
#   '서울특별시 강남구 영동대로96길 12 (삼성동)',
#   '1522-3232'),
#  ('강남논현',
#   '37.5078978596254',
#   '127.023338614644',
#   '서울특별시 강남구 강남대로 512 (논현동)',
#   '1522-3232'),
#  ('테헤란로아남타워',
#   '37.50383',
#   '127.04487',
#   '서울특별시 강남구 테헤란로 311 (역삼동)',
#   '1522-3232'),
#  ('삼성역',
#   '37.509206962541256',
#   '127.06560851480327',
#   '서울특별시 강남구 테헤란로 620 (대치동)',
#   '1522-3232'),
#  ('강남역신분당역사',
#   '37.4970572543978',
#   '127.028180714381',
#   '서울특별시 강남구 강남대로 396 (역삼동)',
#   '1522-3232'),
#  ('언주역', '37.507775', '127.036472', '서울특별시 강남구 봉은사로 222 (역삼동)', '1522-3232'),
# ...
