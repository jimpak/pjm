# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rc, font_manager
font_path='data/fonts/malgun.ttf'
font_path1='c:/Windows/Fonts/malgun.tff'
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

plt.rcParams['axes.unicode_minus']=False

# %%
h=[100,120,130,140,150,160,170,180,190]
f=[200,205,210,220,230,250,270,280,285]
plt.scatter(h,f)
plt.title("키와 발크기 상관관계")
plt.xlabel('키(cm)')
plt.ylabel('발크기(mm)')
# Out:
# Text(0, 0.5, '발크기(mm)')

# %%
df=pd.DataFrame({'h':h, 'f':f})
print(df['h'].corr(df['f']))
print(df.corr())
# Out:
# 0.966126323516351
#           h         f
# h  1.000000  0.966126
# f  0.966126  1.000000

# %%
sns.relplot(x='h', y='f', data=df)
# Out:
# c:\Users\it\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
h1=[100,200,300,400,500,600,700,800,900]
t1=[18.0,17.5,17,16.5,15,13.5,13,12,11]
df=pd.DataFrame({'h':h1,'t':t1})
print(df['h'].corr(df['t']))
print(df.corr())
plt.scatter(h1, t1)
# Out:
# -0.9888665950759702
#           h         t
# h  1.000000 -0.988867
# t -0.988867  1.000000

# %%
sns.relplot(x='h', y='t', data=df)
# Out:
# c:\Users\it\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x=np.random.randint(0,100,50)
y=np.random.randint(0,100,50)
df=pd.DataFrame({'x':x, 'y':y})
print(df.x.corr(df.y))
# Out:
# -0.0825846593301298

# %%
plt.scatter(x,y)

# %%
sns.relplot(x='x',y='y', data=df)
# Out:
# c:\Users\it\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import math
def correlation(x,y):
    n=len(x)
    x_sum=0.0
    y_sum=0.0
    x_sum_pow=0.0
    y_sum_pow=0.0
    mul_xy_sum=0.0

    for i in range(0,n,1):
        mul_xy_sum=mul_xy_sum+float(x[i])*float(y[i])
        x_sum=x_sum+float(x[i])
        y_sum=y_sum+float(y[i])
        x_sum_pow=x_sum_pow+pow(float(x[i]),2)
        y_sum_pow=y_sum_pow+pow(float(y[i]),2)

        r=((n*mul_xy_sum)-(x_sum*y_sum))/ \
        math.sqrt(((n*x_sum_pow)-pow(x_sum,2)) * ((n*y_sum_pow)-pow(y_sum,2)))
    return r

# %%
print(h)
print(f)
print("키와 발크의 상관계수:",correlation(h, f))
print('산의 높이와 기온의 상관계수:', correlation(h1,t1))
print('임의의 x와 y사이의 상관계수:', correlation(x,y))
# Out:
# [100, 120, 130, 140, 150, 160, 170, 180, 190]
# [200, 205, 210, 220, 230, 250, 270, 280, 285]
# 키와 발크의 상관계수: 0.9661263235163509
# 산의 높이와 기온의 상관계수: -0.9888665950759703
# 임의의 x와 y사이의 상관계수: -0.08258465933012982

# %%
tips=sns.load_dataset('tips')
print(tips.total_bill.corr(tips.tip))
sns.relplot(x='total_bill', y='tip', data=tips)
# Out:
# 0.6757341092113641
# c:\Users\it\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
height = [100, 120, 130, 140, 150, 160, 170, 180, 190]
foot_size = [200, 205, 210, 220, 230, 250, 270, 280, 285]
weight=[25, 30, 38, 35, 40, 45, 55, 68, 70]
list=[height,foot_size, weight]
column_names=['height','foot_size','weight']
df=pd.DataFrame(list).T
df.columns=column_names
print(df['height'].corr(df['foot_size']))
print(df['height'].corr(df['weight']))
print(df['weight'].corr(df['foot_size']))
corr=df.corr()
print(corr)
# Out:
# 0.966126323516351
# 0.9522708360712443
# 0.9698070048209746
#              height  foot_size    weight
# height     1.000000   0.966126  0.952271
# foot_size  0.966126   1.000000  0.969807
# weight     0.952271   0.969807  1.000000

# %%
corr_heatmap=sns.heatmap(corr, # value
cbar=True, # 사이브바 표시, defalut True
annot=True, # 값 표시, defalut False
annot_kws={'size':20}, #annot의 글자크기
fmt='.2f', # 숫자형식
square=True, # 정사각형 여부
cmap='Blues') # 색상

# %%
tips=sns.load_dataset('tips')
tips_corr=tips.corr(numeric_only=True)
tips_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
fig,ax=plt.subplots(figsize=(7,7))
mask=np.zeros_like(tips_corr, dtype=np.bool_)
print(mask)
mask[np.triu_indices_from(mask)]=True
print(mask)
# Out:
# [[False False False]
#  [False False False]
#  [False False False]]
# [[ True  True  True]
#  [False  True  True]
#  [False False  True]]

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_corr = titanic.corr(numeric_only=True)
titanic_corr
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
fig,ax = plt.subplots(figsize=(8,8))
mask = np.zeros_like(titanic_corr, dtype=np.bool_)
print(mask)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(titanic_corr, annot=True, mask=mask)
# Out:
# [[False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]
#  [False False False False False False False False]]
# <Axes: >

# %%
fig,ax = plt.subplots(figsize=(8,8))
mask = np.ones_like(titanic_corr, dtype=np.bool_)
print(mask)
mask[np.tril_indices_from(mask)] = False
sns.heatmap(titanic_corr, annot=True, mask=mask)
# Out:
# [[ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]
#  [ True  True  True  True  True  True  True  True]]
# <Axes: >
